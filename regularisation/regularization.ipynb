# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("logistic_data.csv" )
print(data)
# Out:
#      feature1  feature2  target
# 0    0.496714  2.536681       0
# 1   -0.138264  2.841177       1
# 2    0.647689  3.624577       1
# 3    1.523030  3.580703       1
# 4   -0.234153 -0.066504       0
# ..        ...       ...     ...
# 195  0.385317  1.296237       0
# 196 -0.883857 -0.569702       0
# 197  0.153725  4.030809       1
# 198  0.058209  1.828190       0
# 199 -1.142970  3.856724       1
#
# [200 rows x 3 columns]

# %%
X=data.iloc[:,:-1]
Y=data.iloc[:,-1]
print(X)
print(Y)
# Out:
#      feature1  feature2
# 0    0.496714  2.536681
# 1   -0.138264  2.841177
# 2    0.647689  3.624577
# 3    1.523030  3.580703
# 4   -0.234153 -0.066504
# ..        ...       ...
# 195  0.385317  1.296237
# 196 -0.883857 -0.569702
# 197  0.153725  4.030809
# 198  0.058209  1.828190
# 199 -1.142970  3.856724
#
# [200 rows x 2 columns]
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 195    0
# 196    0
# 197    1
# 198    0
# 199    1
# Name: target, Length: 200, dtype: int64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2, random_state=42)

# %%
print(X_train,X_test)
# Out:
#      feature1  feature2
# 79  -1.987569  1.422030
# 197  0.153725  4.030809
# 38  -1.328186  1.007320
# 24  -0.544383  1.292102
# 122  1.402794  0.772669
# ..        ...       ...
# 106  1.886186  3.916497
# 14  -1.724918  1.527096
# 92  -0.702053  1.115953
# 179  2.720169  0.787553
# 102 -0.342715  3.120940
#
# [160 rows x 2 columns]      feature1  feature2
# 95  -1.463515  0.960636
# 15  -0.562288  3.138454
# 30  -0.601707  0.904450
# 158 -1.191303  2.484078
# 128  0.099651  2.936180
# 115  0.301547  2.031506
# 69  -0.645120  2.196111
# 170 -0.889514  2.036765
# 174  0.276691  5.229774
# 45  -0.719844  1.498248
# 66  -0.072010  4.448617
# 182 -1.070892 -1.185844
# 165  0.412781  1.398169
# 78   0.091761  2.104703
# 186  0.473238  2.512634
# 177  1.453534  2.275013
# 56  -0.839218  3.900367
# 152 -0.680025  3.286489
# 82   1.477894  4.379025
# 68   0.361636  1.339933
# 124  0.586857  0.490974
# 16  -1.012831  0.840762
# 148  0.521942  0.922334
# 93  -0.327662  3.274403
# 65   1.356240  0.128325
# 60  -0.479174  0.609604
# 84  -0.808494  5.199550
# 67   1.003533 -0.145212
# 125  2.190456  0.178717
# 132 -1.062304  2.113707
# 9    0.542560  7.779097
# 18  -0.908024  1.271955
# 55   0.931280  1.273649
# 75   0.821903  2.693155
# 150  0.250493  2.466361
# 104 -0.161286  1.968648
# 135  1.549934  1.779414
# 137 -0.322062  1.517921
# 164  0.963376  3.035216
# 76   0.087047  2.298590

# %%
penalty='l1'

# %%
C=0.01

# %%
model=LogisticRegression(penalty=penalty,C=C ,solver='liblinear')

# %%
model.fit(X_train,Y_train)
# Out:
# LogisticRegression(C=0.01, penalty='l1', solver='liblinear')

# %%
accurecy=model.score(X_test,Y_test)
print(accurecy)
# Out:
# 0.525
