# %%
import pandas as pd
pd.__version__
# Out:
# '2.3.0+4.g1dfc98e16a'

# %%
data={'milk_price':[10,15,20],'curd_price':[20,30,40]}

# %%
data
# Out:
# {'milk_price': [10, 15, 20], 'curd_price': [20, 30, 40]}

# %%
type(data)
# Out:
# dict

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    milk_price  curd_price
# 0          10          20
# 1          15          30
# 2          20          40

# %%
df['milk_price']
# Out:
# 0    10
# 1    15
# 2    20
# Name: milk_price, dtype: int64

# %%
df['curd_price']
# Out:
# 0    20
# 1    30
# 2    40
# Name: curd_price, dtype: int64

# %%
df1=pd.read_csv('basketball.csv')

# %%
df1
# Out:
#                   Name            Team  Number Position   Age Height  Weight  \
# 0        Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1          Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2         John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3          R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4        Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5        Isaiah Thomas  Boston Celtics     4.0       PG  28.0    5-9   185.0
# 6         Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   240.0
# 7         Marcus Smart  Boston Celtics    36.0       SG  23.0    6-4   220.0
# 8         Terry Rozier  Boston Celtics    12.0       PG  22.0    6-1   190.0
# 9         Jaylen Brown  Boston Celtics     7.0       SF  21.0    6-6   225.0
# 10          Al Horford  Boston Celtics    42.0        C  30.0   6-10   245.0
# ...

# %%
df1.tail()
# Out:
#                   Name            Team  Number Position   Age Height  Weight  \
# 15   Demetrius Jackson  Boston Celtics     9.0       PG  22.0    6-1   190.0
# 16       Jordan Mickey  Boston Celtics    55.0       PF  24.0    6-8   220.0
# 17  Guerschon Yabusele  Boston Celtics    28.0       PF  23.0    6-8   240.0
# 18          Tacko Fall  Boston Celtics    99.0        C  24.0    7-6   311.0
# 19         Enes Kanter  Boston Celtics    11.0        C  27.0   6-10   250.0
#
#        College     Salary
# 15  Notre Dame   700000.0
# 16         LSU  1200000.0
# 17      France        NaN
# 18         UCF   900000.0
# 19    Kentucky  5000000.0

# %%
df1.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df2=df1[['Name','Salary']]
df2
# Out:
#                   Name      Salary
# 0        Avery Bradley   7730337.0
# 1          Jae Crowder   6796117.0
# 2         John Holland         NaN
# 3          R.J. Hunter   1148640.0
# 4        Jonas Jerebko   5000000.0
# 5        Isaiah Thomas   6510000.0
# 6         Kelly Olynyk   3000000.0
# 7         Marcus Smart   3433333.0
# 8         Terry Rozier   1900000.0
# 9         Jaylen Brown   4100000.0
# 10          Al Horford  27500000.0
# 11        Gerald Green   1450000.0
# 12         James Young         NaN
# 13        Amir Johnson  12000000.0
# 14        Tyler Zeller   8000000.0
# 15   Demetrius Jackson    700000.0
# 16       Jordan Mickey   1200000.0
# 17  Guerschon Yabusele         NaN
# 18          Tacko Fall    900000.0
# 19         Enes Kanter   5000000.0

# %%
df3=pd.read_csv('basketball.csv',usecols=['Name','Salary'])

# %%
df3
# Out:
#                   Name      Salary
# 0        Avery Bradley   7730337.0
# 1          Jae Crowder   6796117.0
# 2         John Holland         NaN
# 3          R.J. Hunter   1148640.0
# 4        Jonas Jerebko   5000000.0
# 5        Isaiah Thomas   6510000.0
# 6         Kelly Olynyk   3000000.0
# 7         Marcus Smart   3433333.0
# 8         Terry Rozier   1900000.0
# 9         Jaylen Brown   4100000.0
# 10          Al Horford  27500000.0
# 11        Gerald Green   1450000.0
# 12         James Young         NaN
# 13        Amir Johnson  12000000.0
# 14        Tyler Zeller   8000000.0
# 15   Demetrius Jackson    700000.0
# 16       Jordan Mickey   1200000.0
# 17  Guerschon Yabusele         NaN
# 18          Tacko Fall    900000.0
# 19         Enes Kanter   5000000.0

# %%
df4=df1.set_index('Name')

# %%
df4
# Out:
#                               Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley       Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder         Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland        Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter         Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko       Boston Celtics     8.0       PF  29.0   6-10   231.0
# Isaiah Thomas       Boston Celtics     4.0       PG  28.0    5-9   185.0
# Kelly Olynyk        Boston Celtics    41.0        C  25.0    7-0   240.0
# Marcus Smart        Boston Celtics    36.0       SG  23.0    6-4   220.0
# Terry Rozier        Boston Celtics    12.0       PG  22.0    6-1   190.0
# Jaylen Brown        Boston Celtics     7.0       SF  21.0    6-6   225.0
# Al Horford          Boston Celtics    42.0        C  30.0   6-10   245.0
# Gerald Green        Boston Celtics    30.0       SG  31.0    6-7   210.0
# ...

# %%
df4.to_csv('new.csv')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      20 non-null     object
#  1   Team      20 non-null     object
#  2   Number    20 non-null     float64
#  3   Position  20 non-null     object
#  4   Age       20 non-null     float64
#  5   Height    20 non-null     object
#  6   Weight    20 non-null     float64
#  7   College   18 non-null     object
#  8   Salary    17 non-null     float64
# dtypes: float64(4), object(5)
# memory usage: 1.5+ KB

# %%
df1.describe()
# Out:
#           Number        Age      Weight        Salary
# count  20.000000  20.000000   20.000000  1.700000e+01
# mean   34.300000  25.350000  223.350000  5.668731e+06
# std    30.681899   2.924938   30.994524  6.440392e+06
# min     0.000000  21.000000  180.000000  7.000000e+05
# 25%    10.500000  23.000000  201.250000  1.450000e+06
# 50%    29.000000  25.000000  222.500000  4.100000e+06
# 75%    42.500000  27.250000  240.000000  6.796117e+06
# max    99.000000  31.000000  311.000000  2.750000e+07

# %%
df1.shape
# Out:
# (20, 9)

# %%
df1.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %%
df1.duplicated().sum()
# Out:
# np.int64(0)

# %%
df1.duplicated(subset=['Team']).sum()
# Out:
# np.int64(19)

# %%
df6 = pd.concat([df1, df1], ignore_index=True)
df6
# Out:
#                   Name            Team  Number Position   Age Height  Weight  \
# 0        Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1          Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2         John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3          R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4        Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5        Isaiah Thomas  Boston Celtics     4.0       PG  28.0    5-9   185.0
# 6         Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   240.0
# 7         Marcus Smart  Boston Celtics    36.0       SG  23.0    6-4   220.0
# 8         Terry Rozier  Boston Celtics    12.0       PG  22.0    6-1   190.0
# 9         Jaylen Brown  Boston Celtics     7.0       SF  21.0    6-6   225.0
# 10          Al Horford  Boston Celtics    42.0        C  30.0   6-10   245.0
# ...

# %%
df6.duplicated().sum()
# Out:
# np.int64(20)

# %%
df7=df6.drop_duplicates()
df7
# Out:
#                   Name            Team  Number Position   Age Height  Weight  \
# 0        Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1          Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2         John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3          R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4        Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5        Isaiah Thomas  Boston Celtics     4.0       PG  28.0    5-9   185.0
# 6         Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   240.0
# 7         Marcus Smart  Boston Celtics    36.0       SG  23.0    6-4   220.0
# 8         Terry Rozier  Boston Celtics    12.0       PG  22.0    6-1   190.0
# 9         Jaylen Brown  Boston Celtics     7.0       SF  21.0    6-6   225.0
# 10          Al Horford  Boston Celtics    42.0        C  30.0   6-10   245.0
# ...

# %%
display(df7.loc[(df7.Team=='Boston Celtics')&(df7.Age>25)])
# Out:
#              Name            Team  Number Position   Age Height  Weight  \
# 2    John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 4   Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Isaiah Thomas  Boston Celtics     4.0       PG  28.0    5-9   185.0
# 10     Al Horford  Boston Celtics    42.0        C  30.0   6-10   245.0
# 11   Gerald Green  Boston Celtics    30.0       SG  31.0    6-7   210.0
# 13   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 14   Tyler Zeller  Boston Celtics    44.0        C  26.0    7-0   250.0
# 19    Enes Kanter  Boston Celtics    11.0        C  27.0   6-10   250.0
#
#               College      Salary
# 2   Boston University         NaN
# 4                 NaN   5000000.0
# 5          Washington   6510000.0
# 10            Florida  27500000.0
# 11                NaN   1450000.0
# 13           Kentucky  12000000.0
# 14     North Carolina   8000000.0
# 19           Kentucky   5000000.0

# %%
df8=df7.loc[4:10]
df8
# Out:
#              Name            Team  Number Position   Age Height  Weight  \
# 4   Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Isaiah Thomas  Boston Celtics     4.0       PG  28.0    5-9   185.0
# 6    Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   240.0
# 7    Marcus Smart  Boston Celtics    36.0       SG  23.0    6-4   220.0
# 8    Terry Rozier  Boston Celtics    12.0       PG  22.0    6-1   190.0
# 9    Jaylen Brown  Boston Celtics     7.0       SF  21.0    6-6   225.0
# 10     Al Horford  Boston Celtics    42.0        C  30.0   6-10   245.0
#
#            College      Salary
# 4              NaN   5000000.0
# 5       Washington   6510000.0
# 6          Gonzaga   3000000.0
# 7   Oklahoma State   3433333.0
# 8       Louisville   1900000.0
# 9       California   4100000.0
# 10         Florida  27500000.0

# %%
df9=df7.loc[(df7.Team=='Boston Celtics'),['Salary']]=1900000

# %%
display(df9)
# Out:
# 1900000

# %%
df10=df7.iloc[10:14,0:2]
display(df10)
# Out:
#             Name            Team
# 10    Al Horford  Boston Celtics
# 11  Gerald Green  Boston Celtics
# 12   James Young  Boston Celtics
# 13  Amir Johnson  Boston Celtics

# %%
df7.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df7.rename(columns={"Name":'name'})
# Out:
#                   name            Team  Number Position   Age Height  Weight  \
# 0        Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1          Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2         John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3          R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4        Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5        Isaiah Thomas  Boston Celtics     4.0       PG  28.0    5-9   185.0
# 6         Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   240.0
# 7         Marcus Smart  Boston Celtics    36.0       SG  23.0    6-4   220.0
# 8         Terry Rozier  Boston Celtics    12.0       PG  22.0    6-1   190.0
# 9         Jaylen Brown  Boston Celtics     7.0       SF  21.0    6-6   225.0
# 10          Al Horford  Boston Celtics    42.0        C  30.0   6-10   245.0
# ...
