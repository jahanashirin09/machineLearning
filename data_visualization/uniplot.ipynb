# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data='iris.csv'

# %% [markdown]
# names=['sepaal-length','sepal-width','petal-length','petal-width']

# %%
names=['sepaal-lengthh','sepal-width','petal-length','petal-width','class']

# %%
dataset=pd.read_csv(data,names=names)

# %%
dataset.plot(kind='bar',sharex=False,sharey=False,subplots=True,layout=(1,4))
# Out:
# array([[<Axes: title={'center': 'sepaal-lengthh'}>,
#         <Axes: title={'center': 'sepal-width'}>,
#         <Axes: title={'center': 'petal-length'}>,
#         <Axes: title={'center': 'petal-width'}>]], dtype=object)
