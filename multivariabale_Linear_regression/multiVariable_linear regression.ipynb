# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plt.style.use('ggplot')
plt.rcParams['figure.figsize']=(12,8)

# %%
advert=pd.read_csv('advertising_data.csv')

# %%
advert.head()
# Out:
#       TV  radio  newspaper  sales
# 0  112.4    1.6       64.2    5.4
# 1  285.2   31.8        8.4   18.2
# 2  219.6   15.7       16.2   15.0
# 3  179.6   25.4       89.9   13.5
# 4   46.8   45.4       60.6    8.6

# %%
advert.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         100 non-null    float64
#  1   radio      100 non-null    float64
#  2   newspaper  100 non-null    float64
#  3   sales      100 non-null    float64
# dtypes: float64(4)
# memory usage: 3.2 KB

# %%
sns.pairplot(advert,x_vars=['TV','radio','newspaper'],y_vars='sales',height=7,aspect=0.7)

# %%
from sklearn.linear_model import LinearRegression
variable=['TV','radio','newspaper']
X=advert[variable]
y=advert.sales
lr=LinearRegression()
lr.fit(x,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [0.04638408 0.19199924 0.0032532 ]
# -0.3918506789509859

# %%
list(zip(variable,lr.coef_))
# Out:
# [('TV', np.float64(0.04638408251982831)),
#  ('radio', np.float64(0.19199923941986818)),
#  ('newspaper', np.float64(0.0032531966835567033))]

# %%
sns.heatmap(advert.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.metrics import mean_squared_error
y_pred=lr.predict(X[['TV','radio','newspaper']])
print(lr.score(X,y))
print(mean_squared_error(y,y_pred))
# Out:
# 0.962442622494622
# 0.9336125196845612
